# %%
import numpy as np
import os

# %%
with open('experiments/test_time/1/low_level_time.npy', 'rb') as f:
    low_level_time_list = np.load(f)

# %%
low_level_time_list
# Out:
# array([0.00348401, 0.00289774, 0.00351644, 0.00364089, 0.0023191 ,
#        0.00279164, 0.00370073, 0.003613  , 0.00232458, 0.00278187,
#        0.00943542, 0.00974679, 0.00812984, 0.00871897, 0.00263429,
#        0.00576735, 0.00295782, 0.00212049, 0.01002383, 0.00922823])

# %%
with open('experiments/test_time/1/training_time.npy', 'rb') as f:
    training_time_list = np.load(f)

# %%
training_time_list
# Out:
# array([0.00642514, 0.00573134, 0.00636888, 0.00733685, 0.0050602 ,
#        0.00533938, 0.00619698, 0.00610614, 0.00438404, 0.00503826,
#        0.01552415, 0.01673126, 0.01727533, 0.01581955, 0.0055213 ,
#        0.00939083, 0.00566578, 0.00467825, 0.01660872, 0.01712394])
